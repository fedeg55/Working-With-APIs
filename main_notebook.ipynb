# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

response = requests.get('https://dog.ceo/api/breeds/list/all')
response
results = response.json()
results
# Out:
# {'message': {'affenpinscher': [],
#   'african': [],
#   'airedale': [],
#   'akita': [],
#   'appenzeller': [],
#   'australian': ['shepherd'],
#   'basenji': [],
#   'beagle': [],
#   'bluetick': [],
#   'borzoi': [],
#   'bouvier': [],
#   'boxer': [],
#   'brabancon': [],
#   'briard': [],
#   'buhund': ['norwegian'],
#   'bulldog': ['boston', 'english', 'french'],
#   'bullterrier': ['staffordshire'],
#   'cattledog': ['australian'],
#   'cavapoo': [],
#   'chihuahua': [],
#   'chow': [],
#   'clumber': [],
#   'cockapoo': [],
#   'collie': ['border'],
#   'coonhound': [],
#   'corgi': ['cardigan'],
#   'cotondetulear': [],
#   'dachshund': [],
#   'dalmatian': [],
#   'dane': ['great'],
#   'deerhound': ['scottish'],
#   'dhole': [],
#   'dingo': [],
#   'doberman': [],
#   'elkhound': ['norwegian'],
#   'entlebucher': [],
#   'eskimo': [],
#   'finnish': ['lapphund'],
#   'frise': ['bichon'],
#   'germanshepherd': [],
#   'greyhound': ['italian'],
#   'groenendael': [],
# ...

# %%
len(results['message'])
# Out:
# 99

# %%
import pandas as pd

data = {
    'breed': [],
    'sub_breed': []
}

for breed, sub_breeds in results['message'].items():
    for sub_breed in sub_breeds:
        data['breed'].append(breed)
        data['sub_breed'].append(sub_breed)

df = pd.DataFrame(data)
df
# Out:
#          breed     sub_breed
# 0   australian      shepherd
# 1       buhund     norwegian
# 2      bulldog        boston
# 3      bulldog       english
# 4      bulldog        french
# ..         ...           ...
# 77     terrier  westhighland
# 78     terrier       wheaten
# 79     terrier     yorkshire
# 80    waterdog       spanish
# 81   wolfhound         irish
#
# [82 rows x 2 columns]

# %%
data_list = [{'Breed': key, 'SubBreed': ', '.join(value) if value else '0'} for key, value in results['message'].items()]
data_list
d = pd.DataFrame.from_dict(data_list)
d.head(20)
# Out:
#             Breed                 SubBreed
# 0   affenpinscher                        0
# 1         african                        0
# 2        airedale                        0
# 3           akita                        0
# 4     appenzeller                        0
# 5      australian                 shepherd
# 6         basenji                        0
# 7          beagle                        0
# 8        bluetick                        0
# 9          borzoi                        0
# 10        bouvier                        0
# 11          boxer                        0
# 12      brabancon                        0
# 13         briard                        0
# 14         buhund                norwegian
# 15        bulldog  boston, english, french
# 16    bullterrier            staffordshire
# 17      cattledog               australian
# 18        cavapoo                        0
# 19      chihuahua                        0

# %% [markdown]
# # second task

# %%
response = requests.get('https://api.imgflip.com/get_memes')
response
results = response.json()
results
# Out:
# {'success': True,
#  'data': {'memes': [{'id': '181913649',
#     'name': 'Drake Hotline Bling',
#     'url': 'https://i.imgflip.com/30b1gx.jpg',
#     'width': 1200,
#     'height': 1200,
#     'box_count': 2,
#     'captions': 0},
#    {'id': '87743020',
#     'name': 'Two Buttons',
#     'url': 'https://i.imgflip.com/1g8my4.jpg',
#     'width': 600,
#     'height': 908,
#     'box_count': 3,
#     'captions': 0},
#    {'id': '112126428',
#     'name': 'Distracted Boyfriend',
#     'url': 'https://i.imgflip.com/1ur9b0.jpg',
#     'width': 1200,
#     'height': 800,
#     'box_count': 3,
#     'captions': 0},
#    {'id': '131087935',
#     'name': 'Running Away Balloon',
#     'url': 'https://i.imgflip.com/261o3j.jpg',
#     'width': 761,
#     'height': 1024,
#     'box_count': 5,
#     'captions': 0},
#    {'id': '217743513',
#     'name': 'UNO Draw 25 Cards',
#     'url': 'https://i.imgflip.com/3lmzyx.jpg',
#     'width': 500,
#     'height': 494,
#     'box_count': 2,
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
# we can mention column names if there are not in data
#data=data[['userId','id','title','completed']]
data.head()
# Out:
#        success                                               data
# memes     True  [{'id': '181913649', 'name': 'Drake Hotline Bl...

# %%
data['data']
# Out:
# memes    [{'id': '181913649', 'name': 'Drake Hotline Bl...
# Name: data, dtype: object

# %%
memes_data = data['data']['memes']
memes_data
# Create a DataFrame
df = pd.DataFrame(memes_data)

df.head()
# Out:
#           id                  name                               url  width  \
# 0  181913649   Drake Hotline Bling  https://i.imgflip.com/30b1gx.jpg   1200
# 1   87743020           Two Buttons  https://i.imgflip.com/1g8my4.jpg    600
# 2  112126428  Distracted Boyfriend  https://i.imgflip.com/1ur9b0.jpg   1200
# 3  131087935  Running Away Balloon  https://i.imgflip.com/261o3j.jpg    761
# 4  217743513     UNO Draw 25 Cards  https://i.imgflip.com/3lmzyx.jpg    500
#
#    height  box_count  captions
# 0    1200          2         0
# 1     908          3         0
# 2     800          3         0
# 3    1024          5         0
# 4     494          2         0

# %% [markdown]
# # third task

# %%
response = requests.get('https://api.fiscaldata.treasury.gov/services/api/fiscal_service/v1/accounting/od/rates_of_exchange?fields=country_currency_desc,exchange_rate, record_date&filter=record_date:gte:2015-01-01')
response
results = response.json()
results
# Out:
# {'data': [{'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '60.26',
#    'record_date': '2015-06-30'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '63.8',
#    'record_date': '2015-09-30'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '68.45',
#    'record_date': '2016-03-31'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '68.22',
#    'record_date': '2016-06-30'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '67.9',
#    'record_date': '2015-12-31'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '57.34',
#    'record_date': '2015-03-31'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '69.32',
#    'record_date': '2017-12-31'},
#   {'country_currency_desc': 'AFGHANISTAN-AFGHANI',
#    'exchange_rate': '65.15',
#    'record_date': '2017-09-30'},
# ...

# %%
df = pd.DataFrame(results['data'])
df.head()
# Out:
#   country_currency_desc exchange_rate record_date
# 0   AFGHANISTAN-AFGHANI         60.26  2015-06-30
# 1   AFGHANISTAN-AFGHANI          63.8  2015-09-30
# 2   AFGHANISTAN-AFGHANI         68.45  2016-03-31
# 3   AFGHANISTAN-AFGHANI         68.22  2016-06-30
# 4   AFGHANISTAN-AFGHANI          67.9  2015-12-31

# %% [markdown]
# # another api

# %%
# response = requests.get('')
# response

# %%
response = requests.get('https://api.hunter.io/v2/')
response
results = response.json()
results
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
response = requests.get('https://docs.rapidapi.com/docs/keys-and-key-rotation')
response
results = response.json()
results
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...
